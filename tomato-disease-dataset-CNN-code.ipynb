# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
trainclasses  = os.listdir("/kaggle/input/tomato-disease-multiple-sources/train")
trainclasses

# %%
trainfiles = []
all_files = []
labels = []

for i in trainclasses:
    trainfiles = [file for file in os.listdir("/kaggle/input/tomato-disease-multiple-sources/train/" + i)]
    for m in trainfiles:
        labels.append(i)
        filestring = "/kaggle/input/tomato-disease-multiple-sources/train/" + i + "/" + m
        all_files.append(filestring)
        

df = pd.DataFrame()
df["filepaths"] = all_files
df["classes"] = labels
df

# %%
testclasses  = os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid")
testfiles =[]
for i in testclasses:
    #print(len(os.listdir("train/"+i)))
    testfiles = testfiles + os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid/"+i)
print(len(testfiles))

# %%
testfiles = []
all_files = []
labels = []

for i in testclasses:
    testfiles = [file for file in os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid/" + i)]
    for m in testfiles:
        labels.append(i)
        filestring = "/kaggle/input/tomato-disease-multiple-sources/valid/" + i + "/" + m
        all_files.append(filestring)
        

df2 = pd.DataFrame()
df2["filepaths"] = all_files
df2["classes"] = labels
df2

# %%
from sklearn.preprocessing import LabelEncoder
classes = ['Late_blight', 'Tomato_Yellow_Leaf_Curl_Virus', 'Septoria_leaf_spot', 'Early_blight',
                'Spider_mites Two-spotted_spider_mite', 'powdery_mildew', 'healthy', 'Bacterial_spot',
                'Target_Spot', 'Tomato_mosaic_virus', 'Leaf_Mold']

label_encoder = LabelEncoder()

df["label"] = label_encoder.fit_transform(df["classes"])
df

# %%
df["label"].value_counts()

# %%
df2["label"] = label_encoder.fit_transform(df2["classes"])
df2

# %%
df2["label"].value_counts()

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
train_data = []
for i in df["filepaths"]:
    image = Image.open(i)
    image = image.resize((128, 128))  # Resize the image to 128x128
    image = np.array(image)
    train_data.append(image)

# %%
len(train_data)

# %%
reshaped_data = []

# Iterate over the elements of train_data and reshape each image
for img in train_data:
    # Check the shape of the image
    if img.shape[2] == 4:
        # Remove the alpha channel if present
        img = img[:, :, :3]
    reshaped_data.append(img)

# Convert the reshaped_data list to a NumPy array
train_data = np.array(reshaped_data)

# Ensure the shape of train_data is (num_samples, 128, 128, 3)
print(train_data.shape)

# Assign train_data to X_train
X_train = train_data

# %%
X_train.shape

# %%
Y_train = np.array(df["label"])
Y_train.shape

# %%
test_data = []
for i in df2["filepaths"]:
    try:
        image = Image.open(i)
        image = image.resize((128, 128))  # Resize the image to 128x128
        image = np.array(image)
        test_data.append(image)
    except:
        print(i)
        index = df2["filepaths"].tolist().index(i)
        df2 = df2.drop(index)
        df2 = df2.reset_index(drop=True)
        continue

# %%
reshaped_data = []

# Iterate over the elements of train_data and reshape each image
for img in test_data:
    # Check the shape of the image
    if img.shape[2] == 4:
        # Remove the alpha channel if present
        img = img[:, :, :3]
    reshaped_data.append(img)

# Convert the reshaped_data list to a NumPy array
test_data = np.array(reshaped_data)

# Ensure the shape of train_data is (num_samples, 128, 128, 3)
print(test_data.shape)

# Assign train_data to X_train
X_test = test_data

# %%
Y_test = np.array(df2["label"])

# %%
Y_test.shape

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(16, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(11, activation='sigmoid')
])

# %%
model.summary()

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history=model.fit(X_train,Y_train, epochs=35, validation_data=(X_test, Y_test))

# Evaluate the model on the testing set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/35
# 808/808 [==============================] - 268s 330ms/step - loss: 0.1204 - accuracy: 0.9739 - val_loss: 6.5493 - val_accuracy: 0.5825
# Epoch 2/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.
35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0875 - accuracy: 0.9835 - val_loss: 9.7737 - val_accuracy: 0.6059
# Epoch 23/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0513 - accuracy: 0.9901 - val_loss: 10.8886 - val_accuracy: 0.6015
# Epoch 24/35
# 808/808 [==============================] - 267s 330ms/step - loss: 0.0812 - accuracy: 0.9857 - val_loss: 9.7603 - val_accuracy: 0.5981
# Epoch 25/35
# 808/808 [==============================] - 268s 331ms/step - loss: 0.0997 - accuracy: 0.9833 - val_loss: 11.5404 - val_accuracy: 0.5890
# Epoch 26/35
# 808/808 [==============================] - 268s 331ms/step - loss: 0.1135 - accuracy: 0.9825 - val_loss: 11.0596 - val_accuracy: 0.5979
# Epoch 27/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0660 - accuracy: 0.9882 - val_loss: 9.6135 - val_accuracy: 0.6005
# Epoch 28/35
# 808/808 [==============================] - 269s 333ms/step - loss: 0.0593 - accuracy: 0.9885 - val_loss: 11.2374 - val_accuracy: 0.5994
# Epoch 29/35
# 808/808 [==============================] - 269s 333ms/step - loss: 0.0732 - accuracy: 0.9869 - val_loss: 10.9563 - val_accuracy: 0.6072
# Epoch 30/35
# 808/808 [==============================] - 269s 333ms/step - loss: 0.1021 - accuracy: 0.9839 - val_loss: 11.1426 - val_accuracy: 0.6048
# Epoch 31/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0604 - accuracy: 0.9891 - val_loss: 11.8259 - val_accuracy: 0.6008
# Epoch 32/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0649 - accuracy: 0.9886 - val_loss: 11.4120 - val_accuracy: 0.6096
# Epoch 33/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0976 - accuracy: 0.9855 - val_loss: 11.1649 - val_accuracy: 0.6020
# Epoch 34/35
# 808/808 [==============================] - 268s 332ms/step - loss: 0.0869 - accuracy: 0.9856 - val_loss: 12.4376 - val_accuracy: 0.6147
# Epoch 35/35
# 808/808 [==============================] - 269s 333ms/step - loss: 0.0808 - accuracy: 0.9874 - val_loss: 12.6221 - val_accuracy: 0.6044
# 209/209 [==============================] - 20s 96ms/step - loss: 12.6221 - accuracy: 0.6044
# Test accuracy: 0.6043692827224731

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

 

# Assuming you have trained your Sequential model and made predictions on the test data
y_pred_probabilities = model.predict(X_test)  # Replace X_test with your test data

 

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.argmax(y_pred_probabilities, axis=1)

 

# Calculate accuracy
accuracy = model.evaluate(X_test, Y_test)[1]  # Replace y_test with your test labels

 

# Calculate precision, recall, and F1 score
precision = precision_score(Y_test, y_pred, average = "macro")
recall = recall_score(Y_test, y_pred, average = "macro")
f1 = f1_score(Y_test, y_pred, average = "macro")

 

# Print the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# 209/209 [==============================] - 20s 96ms/step
# 209/209 [==============================] - 20s 94ms/step - loss: 12.6221 - accuracy: 0.6044
# Accuracy: 0.6043692827224731
# Precision: 0.4715175904383507
# Recall: 0.32935539944606407
# F1 Score: 0.33160806271533244
