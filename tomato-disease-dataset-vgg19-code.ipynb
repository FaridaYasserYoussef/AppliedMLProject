# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
trainclasses  = os.listdir("/kaggle/input/tomato-disease-multiple-sources/train")
trainclasses
# Out:
# ['Late_blight',
#  'Tomato_Yellow_Leaf_Curl_Virus',
#  'Septoria_leaf_spot',
#  'Early_blight',
#  'Spider_mites Two-spotted_spider_mite',
#  'powdery_mildew',
#  'healthy',
#  'Bacterial_spot',
#  'Target_Spot',
#  'Tomato_mosaic_virus',
#  'Leaf_Mold']

# %%
trainfiles = []
all_files = []
labels = []

for i in trainclasses:
    trainfiles = [file for file in os.listdir("/kaggle/input/tomato-disease-multiple-sources/train/" + i)]
    for m in trainfiles:
        labels.append(i)
        filestring = "/kaggle/input/tomato-disease-multiple-sources/train/" + i + "/" + m
        all_files.append(filestring)
        

df = pd.DataFrame()
df["filepaths"] = all_files
df["classes"] = labels
df
# Out:
#                                                filepaths      classes
# 0      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 1      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 2      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 3      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 4      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# ...                                                  ...          ...
# 25846  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25847  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25848  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25849  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25850  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
#
# [25851 rows x 2 columns]

# %%
testclasses  = os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid")
testfiles =[]
for i in testclasses:
    #print(len(os.listdir("train/"+i)))
    testfiles = testfiles + os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid/"+i)
print(len(testfiles))
# Out:
# 6684

# %%
testfiles = []
all_files = []
labels = []

for i in testclasses:
    testfiles = [file for file in os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid/" + i)]
    for m in testfiles:
        labels.append(i)
        filestring = "/kaggle/input/tomato-disease-multiple-sources/valid/" + i + "/" + m
        all_files.append(filestring)
        

df2 = pd.DataFrame()
df2["filepaths"] = all_files
df2["classes"] = labels
df2
# Out:
#                                               filepaths      classes
# 0     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 1     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 2     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 3     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 4     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# ...                                                 ...          ...
# 6679  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6680  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6681  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6682  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6683  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
#
# [6684 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
classes = ['Late_blight', 'Tomato_Yellow_Leaf_Curl_Virus', 'Septoria_leaf_spot', 'Early_blight',
                'Spider_mites Two-spotted_spider_mite', 'powdery_mildew', 'healthy', 'Bacterial_spot',
                'Target_Spot', 'Tomato_mosaic_virus', 'Leaf_Mold']

label_encoder = LabelEncoder()

df["label"] = label_encoder.fit_transform(df["classes"])
df
# Out:
#                                                filepaths      classes  label
# 0      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 1      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 2      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 3      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 4      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# ...                                                  ...          ...    ...
# 25846  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25847  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25848  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25849  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25850  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
#
# [25851 rows x 3 columns]

# %%
df["label"].value_counts()
# Out:
# 2     3113
# 9     3051
# 4     2882
# 0     2826
# 3     2754
# 1     2455
# 8     2153
# 7     2039
# 6     1827
# 5     1747
# 10    1004
# Name: label, dtype: int64

# %%
df2["label"] = label_encoder.fit_transform(df2["classes"])
df2
# Out:
#                                               filepaths      classes  label
# 0     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 1     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 2     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 3     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 4     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# ...                                                 ...          ...    ...
# 6679  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6680  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6681  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6682  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6683  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
#
# [6684 rows x 3 columns]

# %%
df2["label"].value_counts()
# Out:
# 9     806
# 2     792
# 4     746
# 3     739
# 0     732
# 1     643
# 8     584
# 7     498
# 6     457
# 5     435
# 10    252
# Name: label, dtype: int64

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
train_data = []
for i in df["filepaths"]:
    image = Image.open(i)
    image = image.resize((128, 128))  # Resize the image to 128x128
    image = np.array(image)
    train_data.append(image)

# %%
reshaped_data = []

# Iterate over the elements of train_data and reshape each image
for img in train_data:
    # Check the shape of the image
    if img.shape[2] == 4:
        # Remove the alpha channel if present
        img = img[:, :, :3]
    reshaped_data.append(img)

# Convert the reshaped_data list to a NumPy array
train_data = np.array(reshaped_data)

# Ensure the shape of train_data is (num_samples, 128, 128, 3)
print(train_data.shape)

# Assign train_data to X_train
X_train = train_data
# Out:
# (25851, 128, 128, 3)

# %%
X_train.shape
# Out:
# (25851, 128, 128, 3)

# %%
Y_train = np.array(df["label"])
Y_train.shape
# Out:
# (25851,)

# %%
test_data = []
for i in df2["filepaths"]:
    try:
        image = Image.open(i)
        image = image.resize((128, 128))  # Resize the image to 128x128
        image = np.array(image)
        test_data.append(image)
    except:
        print(i)
        index = df2["filepaths"].tolist().index(i)
        df2 = df2.drop(index)
        df2 = df2.reset_index(drop=True)
        continue
# Out:
# /kaggle/input/tomato-disease-multiple-sources/valid/healthy/HL_(336).png

# %%
reshaped_data = []

# Iterate over the elements of train_data and reshape each image
for img in test_data:
    # Check the shape of the image
    if img.shape[2] == 4:
        # Remove the alpha channel if present
        img = img[:, :, :3]
    reshaped_data.append(img)

# Convert the reshaped_data list to a NumPy array
test_data = np.array(reshaped_data)

# Ensure the shape of train_data is (num_samples, 128, 128, 3)
print(test_data.shape)

# Assign train_data to X_train
X_test = test_data
# Out:
# (6683, 128, 128, 3)

# %%
Y_test = np.array(df2["label"])

# %%
Y_test.shape
# Out:
# (6683,)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, models, layers
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import optimizers

# %%
convolutional_base = VGG19(include_top=False, weights='imagenet', input_shape = (128,128, 3))
for layer in convolutional_base.layers:
    layer.trainable = True
convolutional_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 2s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_of_classes = 11
model = models.Sequential()
model.add(convolutional_base)
model.add(layers.Flatten())
model.add(layers.BatchNormalization()) # make sure all values are of same range. it makes the traing process efficient
model.add(layers.Dense(128, activation = "relu"))
model.add(layers.Dropout(0.5)) # turns off neurons to avoid overfitting
model.add(layers.BatchNormalization())
model.add(layers.Dense(64, activation = "relu"))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.Dense(num_of_classes, activation = "softmax"))

# %%
model.compile(
optimizer = optimizers.RMSprop(learning_rate = 2e-5),
loss = keras.losses.sparse_categorical_crossentropy,
metrics = ['acc'])

# %%
model.fit(X_train, Y_train, validation_split = 0.1, epochs = 35)
# Out:
# Epoch 1/35
# 728/728 [==============================] - 147s 175ms/step - loss: 2.7877 - acc: 0.1390 - val_loss: 6.7470 - val_acc: 0.0000e+00
# Epoch 2/35
# 728/728 [==============================] - 124s 171ms/step - loss: 2.3496 - acc: 0.2392 - val_loss: 3.9703 - val_acc: 0.0205
# Epoch 3/35
# 728/728 [==============================] - 126s 173ms/step - loss: 2.0095 - acc: 0.3342 - val_loss: 3.9440 - val_acc: 0.0085
# Epoch 4/35
# 728/728 [==============================] - 125s 172ms/step - loss: 1.8167 - acc: 0.4002 - val_loss: 3.8855 - val_acc: 0.0000e+00
# Epoch 5/35
# 728/728 [==============================] - 126s 173ms/step - loss: 1.6438 - acc: 0.4622 - val_loss: 2.9777 - val_acc: 0.0000e+00
# Epoch 6/35
# 728/728 [==============================] - 126s 173ms/step - loss: 1.4979 - acc: 0.5170 - val_loss: 3.4037 - val_acc: 0.0000e+00
# Epoch 7/35
# 728/728 [==============================] - 126s 173ms/step - loss: 1.4144 - acc: 0.5501 - val_loss: 5.0336 - val_acc: 3.8670e-04
# Epoch 8/35
# 728/728 [==============================] - 125s 171ms/step - loss: 1.2836 - acc: 0.5967 - val_loss: 3.3621 - val_acc: 0.0000e+00
# Epoch 9/35
# 728/728 [==============================] - 126s 173ms/step - loss: 1.1420 - acc: 0.6543 - val_loss: 4.0366 - val_acc: 0.0000e+00
# Epoch 10/35
# 728/728 [==============================] - 126s 173ms/step - loss: 1.0930 - acc: 0.6690 - val_loss: 3.4445 - val_acc: 0.0000e+00
# Epoch 11/35
# 728/728 [==============================] - 125s 172ms/step - loss: 1.0069 - acc: 0.7049 - val_loss: 3.4269 - val_acc: 0.0000e+00
# Epoch 12/35
# 728/728 [==============================] - 125s 171ms/step - loss: 0.9326 - acc: 0.7303 - val_loss: 6.1357 - val_acc: 0.0000e+00
# Epoch 13/35
# 728/728 [==============================] - 125s 172ms/step - loss: 0.8478 - acc: 0.7603 - val_loss: 3.6039 - val_acc: 0.0000e+00
# Epoch 14/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.7872 - acc: 0.7819 - val_loss: 3.9207 - val_acc: 0.0000e+00
# Epoch 15/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.7257 - acc: 0.8022 - val_loss: 4.1282 - val_acc: 0.0000e+00
# Epoch 16/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.6848 - acc: 0.8138 - val_loss: 4.1410 - val_acc: 0.0000e+00
# Epoch 17/35
# 728/728 [==============================] - 125s 172ms/step - loss: 0.6488 - acc: 0.8276 - val_loss: 5.5288 - val_acc: 0.0000e+00
# Epoch 18/35
# 728/728 [==============================] - 125s 171ms/step - loss: 0.6073 - acc: 0.8415 - val_loss: 4.0423 - val_acc: 0.0000e+00
# Epoch 19/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.5726 - acc: 0.8508 - val_loss: 4.1138 - val_acc: 0.0000e+00
# Epoch 20/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.5489 - acc: 0.8554 - val_loss: 4.3109 - val_acc: 0.0000e+00
# Epoch 21/35
# 728/728 [==============================] - 125s 172ms/step - loss: 0.5237 - acc: 0.8652 - val_loss: 4.9602 - val_acc: 0.0000e+00
# Epoch 22/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.4973 - acc: 0.8732 - val_loss: 4.2498 - val_acc: 0.0000e+00
# Epoch 23/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.4762 - acc: 0.8809 - val_loss: 4.1109 - val_acc: 0.0000e+00
# Epoch 24/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.4403 - acc: 0.8879 - val_loss: 3.9841 - val_acc: 0.0000e+00
# Epoch 25/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.4109 - acc: 0.9004 - val_loss: 3.9638 - val_acc: 0.0000e+00
# Epoch 26/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.3874 - acc: 0.9081 - val_loss: 4.9823 - val_acc: 0.0000e+00
# Epoch 27/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.3779 - acc: 0.9090 - val_loss: 4.1912 - val_acc: 0.0000e+00
# Epoch 28/35
# 728/728 [==============================] - 126s 174ms/step - loss: 0.3622 - acc: 0.9115 - val_loss: 4.3716 - val_acc: 0.0000e+00
# Epoch 29/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.3472 - acc: 0.9158 - val_loss: 4.2733 - val_acc: 0.0000e+00
# Epoch 30/35
# 728/728 [==============================] - 125s 172ms/step - loss: 0.3533 - acc: 0.9138 - val_loss: 4.4781 - val_acc: 0.0000e+00
# Epoch 31/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.3193 - acc: 0.9255 - val_loss: 3.9837 - val_acc: 0.0000e+00
# Epoch 32/35
# 728/728 [==============================] - 125s 172ms/step - loss: 0.2982 - acc: 0.9308 - val_loss: 3.9851 - val_acc: 0.0000e+00
# Epoch 33/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.2970 - acc: 0.9298 - val_loss: 4.5085 - val_acc: 0.0000e+00
# Epoch 34/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.2727 - acc: 0.9370 - val_loss: 4.2361 - val_acc: 0.0000e+00
# Epoch 35/35
# 728/728 [==============================] - 126s 173ms/step - loss: 0.2606 - acc: 0.9412 - val_loss: 4.7763 - val_acc: 0.0000e+00

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# Assuming you have trained your Sequential model and made predictions on the test data
y_pred_probabilities = model.predict(X_test)  # Replace X_test with your test data

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.argmax(y_pred_probabilities, axis=1)

# Calculate accuracy
accuracy = model.evaluate(X_test, Y_test)[1]  # Replace y_test with your test labels

# Calculate precision, recall, and F1 score
precision = precision_score(Y_test, y_pred, average = "macro")
recall = recall_score(Y_test, y_pred, average = "macro")
f1 = f1_score(Y_test, y_pred, average = "macro")

# Print the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# 209/209 [==============================] - 12s 58ms/step
# 209/209 [==============================] - 10s 49ms/step - loss: 0.8356 - acc: 0.8149
# Accuracy: 0.8149034976959229
# Precision: 0.7918408212251663
# Recall: 0.8230491697279226
# F1 Score: 0.7974933021984577
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
