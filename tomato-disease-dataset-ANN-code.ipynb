# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
trainclasses  = os.listdir("/kaggle/input/tomato-disease-multiple-sources/train")
trainclasses
# Out:
# ['Late_blight',
#  'Tomato_Yellow_Leaf_Curl_Virus',
#  'Septoria_leaf_spot',
#  'Early_blight',
#  'Spider_mites Two-spotted_spider_mite',
#  'powdery_mildew',
#  'healthy',
#  'Bacterial_spot',
#  'Target_Spot',
#  'Tomato_mosaic_virus',
#  'Leaf_Mold']

# %%
trainfiles = []
all_files = []
labels = []

for i in trainclasses:
    trainfiles = [file for file in os.listdir("/kaggle/input/tomato-disease-multiple-sources/train/" + i)]
    for m in trainfiles:
        labels.append(i)
        filestring = "/kaggle/input/tomato-disease-multiple-sources/train/" + i + "/" + m
        all_files.append(filestring)
        

df = pd.DataFrame()
df["filepaths"] = all_files
df["classes"] = labels
df
# Out:
#                                                filepaths      classes
# 0      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 1      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 2      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 3      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 4      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# ...                                                  ...          ...
# 25846  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25847  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25848  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25849  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 25850  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
#
# [25851 rows x 2 columns]

# %%
testclasses  = os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid")
testfiles =[]
for i in testclasses:
    #print(len(os.listdir("train/"+i)))
    testfiles = testfiles + os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid/"+i)
print(len(testfiles))
# Out:
# 6684

# %%
testfiles = []
all_files = []
labels = []

for i in testclasses:
    testfiles = [file for file in os.listdir("/kaggle/input/tomato-disease-multiple-sources/valid/" + i)]
    for m in testfiles:
        labels.append(i)
        filestring = "/kaggle/input/tomato-disease-multiple-sources/valid/" + i + "/" + m
        all_files.append(filestring)
        

df2 = pd.DataFrame()
df2["filepaths"] = all_files
df2["classes"] = labels
df2
# Out:
#                                               filepaths      classes
# 0     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 1     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 2     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 3     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# 4     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight
# ...                                                 ...          ...
# 6679  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6680  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6681  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6682  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
# 6683  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold
#
# [6684 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
classes = ['Late_blight', 'Tomato_Yellow_Leaf_Curl_Virus', 'Septoria_leaf_spot', 'Early_blight',
                'Spider_mites Two-spotted_spider_mite', 'powdery_mildew', 'healthy', 'Bacterial_spot',
                'Target_Spot', 'Tomato_mosaic_virus', 'Leaf_Mold']

label_encoder = LabelEncoder()

df["label"] = label_encoder.fit_transform(df["classes"])
df
# Out:
#                                                filepaths      classes  label
# 0      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 1      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 2      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 3      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 4      /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# ...                                                  ...          ...    ...
# 25846  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25847  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25848  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25849  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 25850  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
#
# [25851 rows x 3 columns]

# %%
df["label"].value_counts()
# Out:
# 2     3113
# 9     3051
# 4     2882
# 0     2826
# 3     2754
# 1     2455
# 8     2153
# 7     2039
# 6     1827
# 5     1747
# 10    1004
# Name: label, dtype: int64

# %%
df2["label"] = label_encoder.fit_transform(df2["classes"])
df2
# Out:
#                                               filepaths      classes  label
# 0     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 1     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 2     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 3     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# 4     /kaggle/input/tomato-disease-multiple-sources/...  Late_blight      2
# ...                                                 ...          ...    ...
# 6679  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6680  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6681  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6682  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
# 6683  /kaggle/input/tomato-disease-multiple-sources/...    Leaf_Mold      3
#
# [6684 rows x 3 columns]

# %%
df2["label"].value_counts()
# Out:
# 9     806
# 2     792
# 4     746
# 3     739
# 0     732
# 1     643
# 8     584
# 7     498
# 6     457
# 5     435
# 10    252
# Name: label, dtype: int64

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
train_data = []
for i in df["filepaths"]:
    image = Image.open(i)
    image = image.resize((128, 128))  # Resize the image to 128x128
    image = np.array(image)
    train_data.append(image)

# %%
len(train_data)
# Out:
# 25851

# %%
reshaped_data = []

# Iterate over the elements of train_data and reshape each image
for img in train_data:
    # Check the shape of the image
    if img.shape[2] == 4:
        # Remove the alpha channel if present
        img = img[:, :, :3]
    reshaped_data.append(img)

# Convert the reshaped_data list to a NumPy array
train_data = np.array(reshaped_data)

# Ensure the shape of train_data is (num_samples, 128, 128, 3)
print(train_data.shape)

# Assign train_data to X_train
X_train = train_data
# Out:
# (25851, 128, 128, 3)

# %%
X_train.shape
# Out:
# (25851, 128, 128, 3)

# %%
Y_train = np.array(df["label"])
Y_train.shape
# Out:
# (25851,)

# %%
test_data = []
for i in df2["filepaths"]:
    try:
        image = Image.open(i)
        image = image.resize((128, 128))  # Resize the image to 128x128
        image = np.array(image)
        test_data.append(image)
    except:
        print(i)
        index = df2["filepaths"].tolist().index(i)
        df2 = df2.drop(index)
        df2 = df2.reset_index(drop=True)
        continue
# Out:
# /kaggle/input/tomato-disease-multiple-sources/valid/healthy/HL_(336).png

# %%
reshaped_data = []

# Iterate over the elements of train_data and reshape each image
for img in test_data:
    # Check the shape of the image
    if img.shape[2] == 4:
        # Remove the alpha channel if present
        img = img[:, :, :3]
    reshaped_data.append(img)

# Convert the reshaped_data list to a NumPy array
test_data = np.array(reshaped_data)

# Ensure the shape of train_data is (num_samples, 128, 128, 3)
print(test_data.shape)

# Assign train_data to X_train
X_test = test_data
# Out:
# (6683, 128, 128, 3)

# %%
Y_test = np.array(df2["label"])

# %%
Y_test.shape
# Out:
# (6683,)

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# Build the ANN model
model = Sequential()
model.add(Flatten(input_shape=(128, 128, 3)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(len(classes), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, Y_train, epochs=35, validation_data=(X_test, Y_test))

# Evaluate the model and print the test loss and test accuracy
test_loss, test_accuracy = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)
# Out:
# Epoch 1/35
# 808/808 [==============================] - 43s 52ms/step - loss: 428.4354 - accuracy: 0.1833 - val_loss: 176.6180 - val_accuracy: 0.2322
# Epoch 2/35
# 808/808 [==============================] - 42s 51ms/step - loss: 80.0268 - accuracy: 0.2267 - val_loss: 108.9754 - val_accuracy: 0.1459
# Epoch 3/35
# 808/808 [==============================] - 41s 51ms/step - loss: 33.2371 - accuracy: 0.2215 - val_loss: 16.9425 - val_accuracy: 0.2253
# Epoch 4/35
# 808/808 [==============================] - 41s 51ms/step - loss: 18.0985 - accuracy: 0.2381 - val_loss: 8.9046 - val_accuracy: 0.2321
# Epoch 5/35
# 808/808 [==============================] - 41s 51ms/step - loss: 9.7736 - accuracy: 0.2344 - val_loss: 11.0193 - val_accuracy: 0.2328
# Epoch 6/35
# 808/808 [==============================] - 41s 51ms/step - loss: 5.3970 - accuracy: 0.2556 - val_loss: 4.6854 - val_accuracy: 0.1791
# Epoch 7/35
# 808/808 [==============================] - 41s 51ms/step - loss: 3.8921 - accuracy: 0.2731 - val_loss: 2.0982 - val_accuracy: 0.3020
# Epoch 8/35
# 808/808 [==============================] - 42s 52ms/step - loss: 7.3939 - accuracy: 0.1815 - val_loss: 2.3832 - val_accuracy: 0.1097
# Epoch 9/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3617 - accuracy: 0.1203 - val_loss: 2.3555 - val_accuracy: 0.1185
# Epoch 12/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3592 - accuracy: 0.1203 - val_loss: 2.3554 - val_accuracy: 0.1185
# Epoch 13/35
# 808/808 [==============================] - 41s 51ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 14/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3588 - accuracy: 0.1195 - val_loss: 2.3554 - val_accuracy: 0.1185
# Epoch 15/35
# 808/808 [==============================] - 42s 51ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 16/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1199 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 17/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1198 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 18/35
# 808/808 [==============================] - 41s 51ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 19/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1183 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 20/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 21/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1188 - val_loss: 2.3554 - val_accuracy: 0.1185
# Epoch 22/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 23/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 24/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 25/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1199 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 26/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1182 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 27/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 28/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 29/35
# 808/808 [==============================] - 44s 54ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 30/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1179 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 31/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1191 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 32/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3552 - val_accuracy: 0.1185
# Epoch 33/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1204 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 34/35
# 808/808 [==============================] - 43s 53ms/step - loss: 2.3588 - accuracy: 0.1206 - val_loss: 2.3553 - val_accuracy: 0.1185
# Epoch 35/35
# 808/808 [==============================] - 42s 52ms/step - loss: 2.3589 - accuracy: 0.1198 - val_loss: 2.3552 - val_accuracy: 0.1185
# 209/209 [==============================] - 2s 12ms/step - loss: 2.3552 - accuracy: 0.1185
# Test loss: 2.3552310466766357
# Test accuracy: 0.11850965023040771

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

 

# Assuming you have trained your Sequential model and made predictions on the test data
y_pred_probabilities = model.predict(X_test)  # Replace X_test with your test data

 

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.argmax(y_pred_probabilities, axis=1)

 

# Calculate accuracy
accuracy = model.evaluate(X_test, Y_test)[1]  # Replace y_test with your test labels

 

# Calculate precision, recall, and F1 score
precision = precision_score(Y_test, y_pred, average = "macro")
recall = recall_score(Y_test, y_pred, average = "macro")
f1 = f1_score(Y_test, y_pred, average = "macro")

 

# Print the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# 209/209 [==============================] - 2s 12ms/step
# 209/209 [==============================] - 2s 11ms/step - loss: 2.3554 - accuracy: 0.1185
# Accuracy: 0.11850965023040771
# Precision: 0.010773604668562023
# Recall: 0.09090909090909091
# F1 Score: 0.01926421404682274
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
